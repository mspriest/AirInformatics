# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

filepath = "datasets/FacilityLevelGHG_AllCounties.xlsx"

facility_leveldf_dict = pd.read_excel(filepath, None)

# %%
facility_leveldf_dict
# Out:
# {'2019':      REPORTING YEAR                              FACILITY NAME  GHGRP ID  \
#  0              2019                 Hunterstown Combined Cycle   1000475
#  1              2019                Brunot Island Power Station   1007427
#  2              2019                                   Cheswick   1001198
#  3              2019  GUARDIAN INDUSTRIES CORP - FLOREFFE PLANT   1002921
#  4              2019                      Shenango Incorporated   1000235
#  ..              ...                                        ...       ...
#  394            2019                          Panda Liberty LLC   1012196
#  395            2019                              Panda Patriot   1012122
#  396            2019              TGP Station 310 Smethport, PA   1012158
#  397            2019                        UGI Utilities, Inc.   1007356
#  398            2019                   White Compressor Station   1011955
#
#              REPORTED ADDRESS   LATITUDE  LONGITUDE        CITY NAME  \
#  0      1731 Hunterstown Road  39.872500 -77.167200       GETTYSBURG
#  1    2849 WEST CARSON STREET  40.463800 -80.044000       PITTSBURGH
#  2      100 Pittsburgh Street  40.538300 -79.790600       Springdale
#  3       1000 GLASSHOUSE ROAD  40.254237 -79.916438  Jefferson Hills
#  4            200 NEVILLE RD.  40.496700 -80.075600       PITTSBURGH
#  ..                       ...        ...        ...              ...
#  394         151 Liberty Lane  41.769366 -76.479444          Towanda
#  395          50 Patriot Lane  41.188972 -76.895155       Montgomery
#  396     520 Bunker Hill Road  41.769446 -78.429719        Smethport
#  397              1 UGI Drive  40.372376 -75.915056           Denver
#  398             2665 SR 2001  41.681968 -75.871330      Springville
#
#      COUNTY NAME STATE  ZIP CODE                     PARENT COMPANIES  \
#  0         Adams    PA     17325  PLATINUM EQUITY ADVISORS LLC (100%)
#  1     Allegheny    PA     15204            GENON HOLDINGS INC (100%)
#  2     Allegheny    PA     15144            GENON HOLDINGS INC (100%)
#  3     ALLEGHENY    PA     15025      GUARDIAN INDUSTRIES CORP (100%)
#  4     Allegheny    PA     15225                 DTE ENERGY CO (100%)
#  ..          ...   ...       ...                                  ...
#  394         NaN    PA     18848             PANDA POWER FUNDS (100%)
#  395         NaN    PA     17752             PANDA POWER FUNDS (100%)
#  396         NaN    PA     16749             KINDER MORGAN INC (100%)
#  397         NaN    PA     17517                      UGI CORP (100%)
#  398         NaN    PA     18844         WILLIAMS PARTNERS, LP (100%)
#
#       GHG QUANTITY (METRIC TONS CO2e) SUBPARTS
#  0                            2236131      C,D
#  1                              41883      C,D
#  2                             931915      C,D
#  3                                  0      NaN
#  4                                  0      NaN
#  ..                               ...      ...
#  394                          1851549      C,D
#  395                          1442208      C,D
#  396                            40475      C,W
#  397                           155735     NN,W
#  398                                0      NaN
#
#  [399 rows x 13 columns],
#  '2018':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2018; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  393                                               2018
#  394                                               2018
#  395                                               2018
#  396                                               2018
#  397                                               2018
#
#                             Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                 NaN        NaN                    NaN
#  1                                 NaN        NaN                    NaN
#  2                                 NaN        NaN                    NaN
#  3                                 NaN        NaN                    NaN
#  4                                 NaN        NaN                    NaN
#  ..                                ...        ...                    ...
#  393  XTO - Jefferson Township Station    1010913     910 Saxonburg Road
#  394     YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  395                York Energy Center    1000071   1055 Pikes Peak Road
#  396            York Plant Holding LLC    1010680        651 Memory Lane
#  397           ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  393    40.7802  -79.83761     Butler       BUTLER COUNTY         PA
#  394    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  395     39.738   -76.3072      Delta                York         PA
#  396  39.980726 -76.682643       York         YORK COUNTY         PA
#  397  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  393      16002                             EXXONMOBIL CORP (100%)           0
#  394      17406  YORK COUNTY SOLID WASTE & REFUSE AUTHORITY (100%)      144753
#  395      17314                                CALPINE CORP (100%)      811753
#  396      17402                           TALEN ENERGY CORP (100%)        2006
#  397      18826                       WILLIAMS PARTNERS, LP (100%)           0
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  393         NaN
#  394           C
#  395           D
#  396           C
#  397         NaN
#
#  [398 rows x 13 columns],
#  '2017':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2017; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  387                                               2017
#  388                                               2017
#  389                                               2017
#  390                                               2017
#  391                                               2017
#
#                             Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                 NaN        NaN                    NaN
#  1                                 NaN        NaN                    NaN
#  2                                 NaN        NaN                    NaN
#  3                                 NaN        NaN                    NaN
#  4                                 NaN        NaN                    NaN
#  ..                                ...        ...                    ...
#  387  XTO - Jefferson Township Station    1010913     910 Saxonburg Road
#  388     YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  389                York Energy Center    1000071   1055 Pikes Peak Road
#  390            York Plant Holding LLC    1010680        651 Memory Lane
#  391           ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  387    40.7802  -79.83761     Butler       BUTLER COUNTY         PA
#  388    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  389     39.738   -76.3072      Delta                York         PA
#  390  39.980726 -76.682643       York         YORK COUNTY         PA
#  391  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  387      16002                             EXXONMOBIL CORP (100%)           0
#  388      17406  YORK COUNTY SOLID WASTE & REFUSE AUTHORITY (100%)      166273
#  389      17314                                CALPINE CORP (100%)      686392
#  390      17402                           TALEN ENERGY CORP (100%)        2914
#  391      18826                       WILLIAMS PARTNERS, LP (100%)           0
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  387         NaN
#  388           C
#  389           D
#  390           C
#  391         NaN
#
#  [392 rows x 13 columns],
#  '2016':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2016; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  382                                               2016
#  383                                               2016
#  384                                               2016
#  385                                               2016
#  386                                               2016
#
#                             Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                 NaN        NaN                    NaN
#  1                                 NaN        NaN                    NaN
#  2                                 NaN        NaN                    NaN
#  3                                 NaN        NaN                    NaN
#  4                                 NaN        NaN                    NaN
#  ..                                ...        ...                    ...
#  382  XTO - Jefferson Township Station    1010913     910 Saxonburg Road
#  383     YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  384                York Energy Center    1000071   1055 Pikes Peak Road
#  385            York Plant Holding LLC    1010680        651 Memory Lane
#  386           ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  382    40.7802  -79.83761     Butler       BUTLER COUNTY         PA
#  383    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  384     39.738   -76.3072      Delta                York         PA
#  385  39.980726 -76.682643       York         YORK COUNTY         PA
#  386  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  382      16002                             EXXONMOBIL CORP (100%)           0
#  383      17406  YORK COUNTY SOLID WASTE & REFUSE AUTHORITY (100%)      162029
#  384      17314                                CALPINE CORP (100%)      675537
#  385      17402                           TALEN ENERGY CORP (100%)       19734
#  386      18826                       WILLIAMS PARTNERS, LP (100%)           0
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  382         NaN
#  383           C
#  384           D
#  385           C
#  386         NaN
#
#  [387 rows x 13 columns],
#  '2015':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2015; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  376                                               2015
#  377                                               2015
#  378                                               2015
#  379                                               2015
#  380                                               2015
#
#                             Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                 NaN        NaN                    NaN
#  1                                 NaN        NaN                    NaN
#  2                                 NaN        NaN                    NaN
#  3                                 NaN        NaN                    NaN
#  4                                 NaN        NaN                    NaN
#  ..                                ...        ...                    ...
#  376  XTO - Jefferson Township Station    1010913     910 Saxonburg Road
#  377     YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  378                York Energy Center    1000071   1055 Pikes Peak Road
#  379            York Plant Holding LLC    1010680        651 Memory Lane
#  380           ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  376    40.7802  -79.83761     Butler       BUTLER COUNTY         PA
#  377    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  378     39.738   -76.3072      Delta                York         PA
#  379  39.980726 -76.682643       York         YORK COUNTY         PA
#  380  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  376      16002                             EXXONMOBIL CORP (100%)       33538
#  377      17406  YORK COUNTY SOLID WASTE & REFUSE AUTHORITY (100%)      161065
#  378      17314                                CALPINE CORP (100%)      855381
#  379      17402                           Talen Energy Corp (100%)        4287
#  380      18826                       WILLIAMS PARTNERS, LP (100%)       16862
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  376           C
#  377           C
#  378           D
#  379           C
#  380           C
#
#  [381 rows x 13 columns],
#  '2014':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2014; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  364                                               2014
#  365                                               2014
#  366                                               2014
#  367                                               2014
#  368                                               2014
#
#                             Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                 NaN        NaN                    NaN
#  1                                 NaN        NaN                    NaN
#  2                                 NaN        NaN                    NaN
#  3                                 NaN        NaN                    NaN
#  4                                 NaN        NaN                    NaN
#  ..                                ...        ...                    ...
#  364  XTO - Jefferson Township Station    1010913     910 Saxonburg Road
#  365     YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  366                York Energy Center    1000071   1055 Pikes Peak Road
#  367            York Plant Holding LLC    1010680        651 Memory Lane
#  368           ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  364    40.7802  -79.83761     Butler       BUTLER COUNTY         PA
#  365    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  366     39.738   -76.3072      Delta                York         PA
#  367  39.980726 -76.682643       York         YORK COUNTY         PA
#  368  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  364      16002                             EXXONMOBIL CORP (100%)       31653
#  365      17406  York County Solid Waste & Refuse Authority (100%)      160467
#  366      17314                                CALPINE CORP (100%)     1089937
#  367      17402                      York Plant Holding LLC (100%)        6516
#  368      18826                       WILLIAMS PARTNERS, LP (100%)       48769
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  364           C
#  365           C
#  366           D
#  367           C
#  368           C
#
#  [369 rows x 13 columns],
#  '2013':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2013; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  347                                               2013
#  348                                               2013
#  349                                               2013
#  350                                               2013
#  351                                               2013
#
#                            Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                NaN        NaN                    NaN
#  1                                NaN        NaN                    NaN
#  2                                NaN        NaN                    NaN
#  3                                NaN        NaN                    NaN
#  4                                NaN        NaN                    NaN
#  ..                               ...        ...                    ...
#  347  World Kitchen - Charleroi Plant    1009530         100 8th Street
#  348    YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  349               York Energy Center    1000071   1055 Pikes Peak Road
#  350           York Plant Holding LLC    1010680        651 Memory Lane
#  351          ZICK Compressor Station    1011156          147 Russel Rd
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6          Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN        NaN                 NaN        NaN
#  1          NaN        NaN        NaN                 NaN        NaN
#  2          NaN        NaN        NaN                 NaN        NaN
#  3          NaN        NaN        NaN                 NaN        NaN
#  4          NaN        NaN        NaN                 NaN        NaN
#  ..         ...        ...        ...                 ...        ...
#  347  40.143112 -79.899521  Charleroi   WASHINGTON COUNTY         PA
#  348    40.0017   -76.7175       YORK         YORK COUNTY         PA
#  349     39.738   -76.3072      Delta                York         PA
#  350  39.980726 -76.682643       York         YORK COUNTY         PA
#  351  41.747994 -75.748778   Kingsley  SUSQUEHANNA COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  347      15022                           World Litchen LLC (100%)       28053
#  348      17406  York County Solid Waste & Refuse Authority (100%)      158423
#  349      17314                                CALPINE CORP (100%)      865682
#  350      17402                      York Plant Holding LLC (100%)        9783
#  351      18826                       WILLIAMS PARTNERS, LP (100%)       27542
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  347         C,N
#  348           C
#  349           D
#  350           C
#  351           C
#
#  [352 rows x 13 columns],
#  '2012':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2012; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  318                                               2012
#  319                                               2012
#  320                                               2012
#  321                                               2012
#  322                                               2012
#
#                            Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                NaN        NaN                    NaN
#  1                                NaN        NaN                    NaN
#  2                                NaN        NaN                    NaN
#  3                                NaN        NaN                    NaN
#  4                                NaN        NaN                    NaN
#  ..                               ...        ...                    ...
#  318        Wheelabrator - Frackville    1006714           475 MOREA RD
#  319  World Kitchen - Charleroi Plant    1009530         100 8th Street
#  320    YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  321               York Energy Center    1000071   1055 Pikes Peak Road
#  322           York Plant Holding LLC    1010680        651 Memory Lane
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6         Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN         NaN                NaN        NaN
#  1          NaN        NaN         NaN                NaN        NaN
#  2          NaN        NaN         NaN                NaN        NaN
#  3          NaN        NaN         NaN                NaN        NaN
#  4          NaN        NaN         NaN                NaN        NaN
#  ..         ...        ...         ...                ...        ...
#  318    40.7817   -76.1781  FRACKVILLE         Schuylkill         PA
#  319  40.143112 -79.899521   Charleroi  WASHINGTON COUNTY         PA
#  320    40.0017   -76.7175        YORK        YORK COUNTY         PA
#  321     39.738   -76.3072       Delta               York         PA
#  322  39.980726 -76.682643        York        YORK COUNTY         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  318      17931                        WASTE MANAGEMENT INC (100%)      587812
#  319      15022                           World Litchen LLC (100%)       26577
#  320      17406  York County Solid Waste & Refuse Authority (100%)      163829
#  321      17314                                CALPINE CORP (100%)     1416481
#  322      17402                      York Plant Holding LLC (100%)       29785
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  318           D
#  319         C,N
#  320           C
#  321           D
#  322           C
#
#  [323 rows x 13 columns],
#  '2011':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2011; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  301                                               2011
#  302                                               2011
#  303                                               2011
#  304                                               2011
#  305                                               2011
#
#                            Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                NaN        NaN                    NaN
#  1                                NaN        NaN                    NaN
#  2                                NaN        NaN                    NaN
#  3                                NaN        NaN                    NaN
#  4                                NaN        NaN                    NaN
#  ..                               ...        ...                    ...
#  301         Westwood Generation, LLC    1001249   490 West Main Street
#  302        Wheelabrator - Frackville    1006714           475 MOREA RD
#  303  World Kitchen - Charleroi Plant    1009530         100 8th Street
#  304    YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#  305               York Energy Center    1000071   1055 Pikes Peak Road
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6         Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN         NaN                NaN        NaN
#  1          NaN        NaN         NaN                NaN        NaN
#  2          NaN        NaN         NaN                NaN        NaN
#  3          NaN        NaN         NaN                NaN        NaN
#  4          NaN        NaN         NaN                NaN        NaN
#  ..         ...        ...         ...                ...        ...
#  301    40.6191     -76.45     TREMONT         Schuylkill         PA
#  302    40.7817   -76.1781  FRACKVILLE         Schuylkill         PA
#  303  40.143112 -79.899521   Charleroi  WASHINGTON COUNTY         PA
#  304    40.0017   -76.7175        YORK               YORK         PA
#  305     39.738   -76.3072       Delta               York         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  301      17981                   INTEGRYS ENERGY GROUP INC (100%)      332417
#  302      17931                        WASTE MANAGEMENT INC (100%)      599190
#  303      15022                           World Litchen LLC (100%)       30617
#  304      17406  York County Solid Waste & Refuse Authority (100%)      152860
#  305      17314                                CALPINE CORP (100%)      395154
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  301         C,D
#  302           D
#  303         C,N
#  304           C
#  305           D
#
#  [306 rows x 13 columns],
#  '2010':     Data Extracted from EPA's FLIGHT Tool (http://ghgdata.epa.gov/ghgp)  \
#  0    The data was reported to EPA by facilities as ...
#  1    All emissions data is presented in units of me...
#  2    GHG data for some source categories are not di...
#  3    Search Parameters: year=2010; state=PA; GHGs=A...
#  4                                                  NaN
#  ..                                                 ...
#  263                                               2010
#  264                                               2010
#  265                                               2010
#  266                                               2010
#  267                                               2010
#
#                            Unnamed: 1 Unnamed: 2             Unnamed: 3  \
#  0                                NaN        NaN                    NaN
#  1                                NaN        NaN                    NaN
#  2                                NaN        NaN                    NaN
#  3                                NaN        NaN                    NaN
#  4                                NaN        NaN                    NaN
#  ..                               ...        ...                    ...
#  263     WSI Sandy Run Landfill, Inc.    1004321      995 Landfill Road
#  264         Westwood Generation, LLC    1001249   490 West Main Street
#  265        Wheelabrator - Frackville    1006714           475 MOREA RD
#  266  World Kitchen - Charleroi Plant    1009530         100 8th Street
#  267    YORK COUNTY RESOURCE RECOVERY    1006647  2651 BLACKBRIDGE ROAD
#
#      Unnamed: 4 Unnamed: 5  Unnamed: 6         Unnamed: 7 Unnamed: 8  \
#  0          NaN        NaN         NaN                NaN        NaN
#  1          NaN        NaN         NaN                NaN        NaN
#  2          NaN        NaN         NaN                NaN        NaN
#  3          NaN        NaN         NaN                NaN        NaN
#  4          NaN        NaN         NaN                NaN        NaN
#  ..         ...        ...         ...                ...        ...
#  263  40.129127 -78.201406    Hopewell            BEDFORD         PA
#  264    40.6191     -76.45     TREMONT         Schuylkill         PA
#  265    40.7817   -76.1781  FRACKVILLE         Schuylkill         PA
#  266  40.143112 -79.899521   Charleroi  WASHINGTON COUNTY         PA
#  267    40.0017   -76.7175        YORK               YORK         PA
#
#      Unnamed: 9                                        Unnamed: 10 Unnamed: 11  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                                NaN         NaN
#  2          NaN                                                NaN         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                                NaN         NaN
#  ..         ...                                                ...         ...
#  263      16650                WSI Sandy Run Landfill, Inc. (100%)       63335
#  264      17981                   Integrys Energy Group Inc (100%)      321855
#  265      17931                        Waste Management Inc (100%)      520279
#  266      15022                           World Kitchen LLC (100%)       26991
#  267      17406  York County Solid Waste & Refuse Authority (100%)      142728
#
#      Unnamed: 12
#  0           NaN
#  1           NaN
#  2           NaN
#  3           NaN
#  4           NaN
#  ..          ...
#  263          HH
#  264         C,D
#  265           D
#  266         C,N
#  267           C
#
#  [268 rows x 13 columns]}

# %%
for key in facility_leveldf_dict:
    
    if key == "2019": 
        continue
    new_column_names = list(facility_leveldf_dict[key].iloc[5,:])
    facility_leveldf_dict[key].columns = new_column_names
    facility_leveldf_dict[key] = facility_leveldf_dict[key].drop([0,1,2,3,4,5])

# %%
for key in facility_leveldf_dict:
    
    facility_leveldf_dict[key] = facility_leveldf_dict[key].reset_index(drop=True)
    facility_leveldf_dict[key]['COUNTY NAME'] = facility_leveldf_dict[key]['COUNTY NAME'].str.lower()
    facility_leveldf_dict[key]['COUNTY NAME'] = facility_leveldf_dict[key]['COUNTY NAME'].str.replace("county", "")
    facility_leveldf_dict[key]['COUNTY NAME'] = facility_leveldf_dict[key]['COUNTY NAME'].str.replace(" ", "")
    facility_leveldf_dict[f'{key}'] = facility_leveldf_dict[f'{key}'].replace(np.nan, 'Empty', regex=True)

# %%
bar_2019ghg_sums = facility_leveldf_dict['2019'].groupby(["COUNTY NAME"]).sum(["GHG QUANTITY (METRIC TONS CO2e)"])

# %%
facility_leveldf_dict['2019']
# Out:
#      REPORTING YEAR                              FACILITY NAME  GHGRP ID  \
# 0              2019                 Hunterstown Combined Cycle   1000475
# 1              2019                Brunot Island Power Station   1007427
# 2              2019                                   Cheswick   1001198
# 3              2019  GUARDIAN INDUSTRIES CORP - FLOREFFE PLANT   1002921
# 4              2019                      Shenango Incorporated   1000235
# ..              ...                                        ...       ...
# 394            2019                          Panda Liberty LLC   1012196
# 395            2019                              Panda Patriot   1012122
# 396            2019              TGP Station 310 Smethport, PA   1012158
# 397            2019                        UGI Utilities, Inc.   1007356
# 398            2019                   White Compressor Station   1011955
#
#             REPORTED ADDRESS   LATITUDE  LONGITUDE        CITY NAME  \
# 0      1731 Hunterstown Road  39.872500 -77.167200       GETTYSBURG
# 1    2849 WEST CARSON STREET  40.463800 -80.044000       PITTSBURGH
# 2      100 Pittsburgh Street  40.538300 -79.790600       Springdale
# 3       1000 GLASSHOUSE ROAD  40.254237 -79.916438  Jefferson Hills
# 4            200 NEVILLE RD.  40.496700 -80.075600       PITTSBURGH
# ..                       ...        ...        ...              ...
# 394         151 Liberty Lane  41.769366 -76.479444          Towanda
# 395          50 Patriot Lane  41.188972 -76.895155       Montgomery
# 396     520 Bunker Hill Road  41.769446 -78.429719        Smethport
# 397              1 UGI Drive  40.372376 -75.915056           Denver
# 398             2665 SR 2001  41.681968 -75.871330      Springville
#
#     COUNTY NAME STATE  ZIP CODE                     PARENT COMPANIES  \
# 0         adams    PA     17325  PLATINUM EQUITY ADVISORS LLC (100%)
# 1     allegheny    PA     15204            GENON HOLDINGS INC (100%)
# 2     allegheny    PA     15144            GENON HOLDINGS INC (100%)
# 3     allegheny    PA     15025      GUARDIAN INDUSTRIES CORP (100%)
# 4     allegheny    PA     15225                 DTE ENERGY CO (100%)
# ..          ...   ...       ...                                  ...
# 394       Empty    PA     18848             PANDA POWER FUNDS (100%)
# 395       Empty    PA     17752             PANDA POWER FUNDS (100%)
# 396       Empty    PA     16749             KINDER MORGAN INC (100%)
# 397       Empty    PA     17517                      UGI CORP (100%)
# 398       Empty    PA     18844         WILLIAMS PARTNERS, LP (100%)
#
#      GHG QUANTITY (METRIC TONS CO2e) SUBPARTS
# 0                            2236131      C,D
# 1                              41883      C,D
# 2                             931915      C,D
# 3                                  0    Empty
# 4                                  0    Empty
# ..                               ...      ...
# 394                          1851549      C,D
# 395                          1442208      C,D
# 396                            40475      C,W
# 397                           155735     NN,W
# 398                                0    Empty
#
# [399 rows x 13 columns]

# %%
bar_2019ghg_sums = bar_2019ghg_sums.drop(columns=['REPORTING YEAR','GHGRP ID', 'LATITUDE', 'LONGITUDE', 'ZIP CODE'])

# %%
bar_2019ghg_sumsascending = bar_2019ghg_sums.sort_values(["GHG QUANTITY (METRIC TONS CO2e)"], ascending=False)
bar_2019ghg_sumsascending
# Out:
#              GHG QUANTITY (METRIC TONS CO2e)
# COUNTY NAME
# indiana                             19618927
# armstrong                           11010515
# allegheny                            8522128
# greene                               7268728
# delaware                             5760964
# ...                                      ...
# huntingdon                             47221
# columbia                               46855
# pike                                   29147
# bedford                                15381
# sullivan                                   0
#
# [65 rows x 1 columns]

# %%
# Chart our data, give it a title, and label the axes
ghgsum_2019bar = bar_2019ghg_sumsascending.plot(kind="bar", title="Total GHG Emissions (Metric Tons of CO2)")
ghgsum_2019bar.set_xlabel("County Name")
ghgsum_2019bar.set_ylabel("Metric Tons of CO2")

plt.show()

# %%
# Chart our data, give it a title, and label the axes

x = []
y = []
county_list = list(bar_2019ghg_sumsascending.index)

for i in range(11):
    
    y.append(bar_2019ghg_sumsascending.iloc[i,0])
    x.append(county_list[i])

bar_2019top5ghg_sums = pd.DataFrame({"GHG Emissions": y}, index = x)
    
ghgsumtop5_2019bar = bar_2019top5ghg_sums.plot(kind="bar", title="Top 10 GHG Emissions in PA by County (Metric Tons of CO2)")
ghgsumtop5_2019bar.set_xlabel("County Name")
ghgsumtop5_2019bar.set_ylabel("Metric Tons of CO2")

plt.show()

# %%
plt.title("CO2 Emissions vs. Latitude (2019)")
plt.xlabel("Latitude")
plt.ylabel("CO2 Emissions (Metric Tons)")
plt.scatter(facility_leveldf_dict['2019']["LATITUDE"], facility_leveldf_dict['2019']["GHG QUANTITY (METRIC TONS CO2e)"], marker="o", color="magenta")
plt.show()

# %%
plt.title("CO2 Emissions vs. Latitude (2019)")
plt.xlabel("Longitude")
plt.ylabel("CO2 Emissions (Metric Tons)")
plt.scatter(facility_leveldf_dict['2019']["LONGITUDE"], facility_leveldf_dict['2019']["GHG QUANTITY (METRIC TONS CO2e)"], marker="o", color="magenta")
plt.show()

# %%
bar_2019ghg_parentcompany_sums = facility_leveldf_dict['2019'].groupby(["PARENT COMPANIES"]).sum(["GHG QUANTITY (METRIC TONS CO2e)"]).sort_values(["GHG QUANTITY (METRIC TONS CO2e)"], ascending=False)


bar_2019ghg_parentcompany_sums = bar_2019ghg_parentcompany_sums.drop(columns=['REPORTING YEAR','GHGRP ID', 'LATITUDE', 'LONGITUDE', 'ZIP CODE'])
bar_2019ghg_parentcompany_sums.head(10)
# Out:
#                                                     GHG QUANTITY (METRIC TONS CO2e)
# PARENT COMPANIES
# ARCLIGHT CAPITAL PARTNERS,LLC (67.29%); BOWFIN ...                         10546345
# ARCLIGHT CAPITAL PARTNERS,LLC (57.61%); UGI COR...                         10483904
# CONSOL ENERGY INC (100%)                                                    7599282
# EFS-N LLC (100%)                                                            7013295
# US STEEL CORP (100%)                                                        5186910
# Vistra Energy Corp (100%)                                                   4965154
# TALEN ENERGY CORP (100%)                                                    4457202
# VOLT PARENT LP (100%)                                                       3908462
# INVENERGY LLC (100%)                                                        3633234
# PANDA POWER FUNDS (100%)                                                    3293757

# %%
# Chart our data, give it a title, and label the axes

x = []
y = []
company_list = list(bar_2019ghg_parentcompany_sums.index)

for i in range(20):
    
    y.append(bar_2019ghg_parentcompany_sums.iloc[i,0])
    x.append(company_list[i])

parents_2019top20ghg_sums = pd.DataFrame({"GHG Emissions": y}, index = x)
    
parenttop20_2019bar = parents_2019top20ghg_sums.plot(kind="bar", title="Top 10 GHG Emissions in PA by County (Metric Tons of CO2)")
parenttop20_2019bar.set_xlabel("Parent Company Name")
parenttop20_2019bar.set_ylabel("Metric Tons of CO2")

plt.show()

# %%
# Chart our data, give it a title, and label the axes

x = []
y = []
company_list = list(bar_2019ghg_parentcompany_sums.index)

for i in range(5):
    
    y.append(bar_2019ghg_parentcompany_sums.iloc[i,0])
    x.append(company_list[i])

parents_2019top20ghg_sums = pd.DataFrame({"GHG Emissions": y}, index = x)
    
parenttop20_2019bar = parents_2019top20ghg_sums.plot(kind="bar", title="Top 10 GHG Emissions in PA by County (Metric Tons of CO2)")
parenttop20_2019bar.set_xlabel("Parent Company Name")
parenttop20_2019bar.set_ylabel("Metric Tons of CO2")


plt.show()

# %%
from sqlalchemy import create_engine

dataoutput_path = '/datasets/superclean_facilities.db'
engine = create_engine(f'sqlite://{dataoutput_path}', echo=False)
sqlite_connection = engine.connect()

# %%
for dataframe in facility_leveldf_dict:

    facility_leveldf_dict[f'{dataframe}'].to_sql(f'facility_leveldf_{dataframe}', sqlite_connection)

# %%
#Reference: https://stackoverflow.com/questions/38406328/how-to-correctly-write-out-a-tsv-file-from-a-series-in-pandas
#Reference: https://stackoverflow.com/questions/57209564/write-dictionary-of-dataframes-to-separate-excel-sheets

with pd.ExcelWriter('datasets/facilities_clean.xlsx') as writer: 
    
    for dataframe in facility_leveldf_dict: 
        
        facility_leveldf_dict[f'{dataframe}'].to_excel(writer, sheet_name=f'{dataframe}', index=False)

# %%
#Writing cleaned data to json file
#Reference: https://www.geeksforgeeks.org/reading-and-writing-json-to-a-file-in-python/
#Reference: https://stackoverflow.com/questions/26837998/pandas-replace-nan-with-blank-empty-string
#Reference: https://www.guru99.com/python-dictionary-append.html

import json

dictionary = {"2019": [],"2018": [], "2017": [], "2016": [], "2015": [], "2014": [], "2013": [], "2012": [], "2011": [], "2010": []}
test_dict = facility_leveldf_dict

for key in test_dict: 
    
    page = test_dict[f'{key}'].to_dict(orient='index')
    dictionary[f'{key}'].append(page)

# %%
# Serializing json 
json_object = json.dumps(dictionary)
  
# Writing to sample.json
with open("datasets/clean_facilities.json", "w") as outfile:
    outfile.write(json_object)

# %%
json_object
# Out:
# '{"2019": [{"0": {"REPORTING YEAR": 2019, "FACILITY NAME": "Hunterstown Combined Cycle", "GHGRP ID": 1000475, "REPORTED ADDRESS": "1731 Hunterstown Road", "LATITUDE": 39.8725, "LONGITUDE": -77.1672, "CITY NAME": "GETTYSBURG", "COUNTY NAME": "adams", "STATE": "PA", "ZIP CODE": 17325, "PARENT COMPANIES": "PLATINUM EQUITY ADVISORS LLC (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 2236131, "SUBPARTS": "C,D"}, "1": {"REPORTING YEAR": 2019, "FACILITY NAME": "Brunot Island Power Station", "GHGRP ID": 1007427, "REPORTED ADDRESS": "2849 WEST CARSON STREET", "LATITUDE": 40.4638, "LONGITUDE": -80.044, "CITY NAME": "PITTSBURGH", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15204, "PARENT COMPANIES": "GENON HOLDINGS INC (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 41883, "SUBPARTS": "C,D"}, "2": {"REPORTING YEAR": 2019, "FACILITY NAME": "Cheswick", "GHGRP ID": 1001198, "REPORTED ADDRESS": "100 Pittsburgh Street", "LATITUDE": 40.5383, "LONGITUDE": -79.7906, "CITY NAME": "Springdale", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15144, "PARENT COMPANIES": "GENON HOLDINGS INC (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 931915, "SUBPARTS": "C,D"}, "3": {"REPORTING YEAR": 2019, "FACILITY NAME": "GUARDIAN INDUSTRIES CORP - FLOREFFE PLANT", "GHGRP ID": 1002921, "REPORTED ADDRESS": "1000 GLASSHOUSE ROAD", "LATITUDE": 40.254237, "LONGITUDE": -79.916438, "CITY NAME": "Jefferson Hills", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15025, "PARENT COMPANIES": "GUARDIAN INDUSTRIES CORP (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 0, "SUBPARTS": "Empty"}, "4": {"REPORTING YEAR": 2019, "FACILITY NAME": "Shenango Incorporated", "GHGRP ID": 1000235, "REPORTED ADDRESS": "200 NEVILLE RD.", "LATITUDE": 40.4967, "LONGITUDE": -80.0756, "CITY NAME": "PITTSBURGH", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15225, "PARENT COMPANIES": "DTE ENERGY CO (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 0, "SUBPARTS": "Empty"}, "5": {"REPORTING YEAR": 2019, "FACILITY NAME": "Springdale Generating Station (55196)", "GHGRP ID": 1007659, "REPORTED ADDRESS": "Empty", "LATITUDE": 40.5447, "LONGITUDE": -79.7678, "CITY NAME": "SPRINGDALE", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15144, "PARENT COMPANIES": "LS Power Development, LLC (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 67395, "SUBPARTS": "D"}, "6": {"REPORTING YEAR": 2019, "FACILITY NAME": "Springdale Generating Station (55710)", "GHGRP ID": 1007360, "REPORTED ADDRESS": "Empty", "LATITUDE": 40.5456, "LONGITUDE": -79.7669, "CITY NAME": "SPRINGDALE", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15144, "PARENT COMPANIES": "LS Power Development, LLC (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 1567037, "SUBPARTS": "D"}, "7": {"REPORTING YEAR": 2019, "FACILITY NAME": "US Steel (Clairton Coke)", "GHGRP ID": 1000124, "REPORTED ADDRESS": "400 STATE ST", "LATITUDE": 40.3097, "LONGITUDE": -79.8819, "CITY NAME": "CLAIRTON", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15025, "PARENT COMPANIES": "US STEEL CORP (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 954171, "SUBPARTS": "C,Q"}, "8": {"REPORTING YEAR": 2019, "FACILITY NAME": "US Steel (Edgar Thomson)", "GHGRP ID": 1000233, "REPORTED ADDRESS": "13th Street and Braddock Avenue", "LATITUDE": 40.3925, "LONGITUDE": -79.8564, "CITY NAME": "Braddock", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15104, "PARENT COMPANIES": "US STEEL CORP (100%)", "GHG QUANTITY (METRIC TONS CO2e)": 3639506, "SUBPARTS": "C,Q"}, "9": {"REPORTING YEAR": 2019, "FACILITY NAME": "University of Pittsburgh Applied Research Center/UPARC", "GHGRP ID": 1003758, "REPORTED ADDRESS": "3170 William Pitt Way", "LATITUDE": 40.542087, "LONGITUDE": -79.835308, "CITY NAME": "Pittsburgh", "COUNTY NAME": "allegheny", "STATE": "PA", "ZIP CODE": 15238, "PARENT COMPANIES": "UNIVERSITY OF PITTSBURGH (100%);", "GHG QUANTITY (METRIC TONS CO2e)": 0, "SUBPARTS": "Empty"}, "10": {"REPORTING YEAR": 2019, "FACILITY NAME": "University of Pittsburgh/Carrillo Street S ...
